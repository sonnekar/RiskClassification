# %% [markdown]
# terms = [
#     "Gravity",
#     "Motion",
#     "Mechanical",
#     "Electrical",
#     "Pressure",
#     "Sound",
#     "Radiation",
#     "Biological",
#     "Chemical",
#     "Temperature"
# ]

# %%
import ollama

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from typing import Dict, List, Tuple, Optional

df = pd.read_csv('/Users/jacktaylor2/Desktop/hack12/hack12/dataset/CORE_HackOhio_subset_cleaned_downsampled 1.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 import matplotlib.pyplot as plt
#       6 from typing import Dict, List, Tuple, Optional
# ----> 8 df = pd.read_csv('/Users/jacktaylor2/Desktop/hack12/hack12/dataset/CORE_HackOhio_subset_cleaned_downsampled 1.csv')
#      10 df.head()
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jacktaylor2/Desktop/hack12/hack12/dataset/CORE_HackOhio_subset_cleaned_downsampled 1.csv'

# %%
df.set_index('OBSRVTN_NB', inplace=True)
df.head()
# Out:
#                 DATETIME_DTM  \
# OBSRVTN_NB
# 330560       3/15/2023 11:01
# 164330        7/9/2019 10:00
# 265239        8/1/2022 10:15
# 404438      10/18/2023 12:06
# 83172         3/3/2021 11:00
#
#                                                        PNT_NM  \
# OBSRVTN_NB
# 330560      Did you recognize additional slip, trip, or fa...
# 164330                            Vehicle Operating Condition
# 265239                           Suspended Load/Overhead Work
# 404438                                        PPE - Workforce
# 83172                                   Climbing - Procedures
#
#                                                QUALIFIER_TXT  \
# OBSRVTN_NB
# 330560                              Awareness of environment
# 164330                   Other - Vehicle Operating Condition
# 265239                  Other - Suspended Load/Overhead Work
# 404438                                 Other - PPE Workforce
# 83172       Was a drop zone established, and clearly marked?
#
#                                            PNT_ATRISKNOTES_TX  \
# OBSRVTN_NB
# 330560      [NAME] was working a near by cliff that had ab...
# 164330      [NAME] trucks with cut out bumbers need a hitc...
# 265239      Employee rigged a concrete culvert to be off l...
# 404438      [NAME] tender was not wearing his Hardhat. I r...
# 83172       A drop zone was not clearly marked by the crew...
#
#                                        PNT_ATRISKFOLWUPNTS_TX
# OBSRVTN_NB
# 330560                                                    NaN
# 164330                                                    NaN
# 265239      Coached employee that once he had the culverts...
# 404438                                                    NaN
# 83172                                                     NaN

# %%
df.fillna("NA", inplace=True)
df.head()
# Out:
#                 DATETIME_DTM  \
# OBSRVTN_NB
# 330560       3/15/2023 11:01
# 164330        7/9/2019 10:00
# 265239        8/1/2022 10:15
# 404438      10/18/2023 12:06
# 83172         3/3/2021 11:00
#
#                                                        PNT_NM  \
# OBSRVTN_NB
# 330560      Did you recognize additional slip, trip, or fa...
# 164330                            Vehicle Operating Condition
# 265239                           Suspended Load/Overhead Work
# 404438                                        PPE - Workforce
# 83172                                   Climbing - Procedures
#
#                                                QUALIFIER_TXT  \
# OBSRVTN_NB
# 330560                              Awareness of environment
# 164330                   Other - Vehicle Operating Condition
# 265239                  Other - Suspended Load/Overhead Work
# 404438                                 Other - PPE Workforce
# 83172       Was a drop zone established, and clearly marked?
#
#                                            PNT_ATRISKNOTES_TX  \
# OBSRVTN_NB
# 330560      [NAME] was working a near by cliff that had ab...
# 164330      [NAME] trucks with cut out bumbers need a hitc...
# 265239      Employee rigged a concrete culvert to be off l...
# 404438      [NAME] tender was not wearing his Hardhat. I r...
# 83172       A drop zone was not clearly marked by the crew...
#
#                                        PNT_ATRISKFOLWUPNTS_TX
# OBSRVTN_NB
# 330560                                                     NA
# 164330                                                     NA
# 265239      Coached employee that once he had the culverts...
# 404438                                                     NA
# 83172                                                      NA

# %%
df['DATETIME_DTM'] = pd.to_datetime(df['DATETIME_DTM'])
df.head()
# Out:
#                   DATETIME_DTM  \
# OBSRVTN_NB
# 330560     2023-03-15 11:01:00
# 164330     2019-07-09 10:00:00
# 265239     2022-08-01 10:15:00
# 404438     2023-10-18 12:06:00
# 83172      2021-03-03 11:00:00
#
#                                                        PNT_NM  \
# OBSRVTN_NB
# 330560      Did you recognize additional slip, trip, or fa...
# 164330                            Vehicle Operating Condition
# 265239                           Suspended Load/Overhead Work
# 404438                                        PPE - Workforce
# 83172                                   Climbing - Procedures
#
#                                                QUALIFIER_TXT  \
# OBSRVTN_NB
# 330560                              Awareness of environment
# 164330                   Other - Vehicle Operating Condition
# 265239                  Other - Suspended Load/Overhead Work
# 404438                                 Other - PPE Workforce
# 83172       Was a drop zone established, and clearly marked?
#
#                                            PNT_ATRISKNOTES_TX  \
# OBSRVTN_NB
# 330560      [NAME] was working a near by cliff that had ab...
# 164330      [NAME] trucks with cut out bumbers need a hitc...
# 265239      Employee rigged a concrete culvert to be off l...
# 404438      [NAME] tender was not wearing his Hardhat. I r...
# 83172       A drop zone was not clearly marked by the crew...
#
#                                        PNT_ATRISKFOLWUPNTS_TX
# OBSRVTN_NB
# 330560                                                     NA
# 164330                                                     NA
# 265239      Coached employee that once he had the culverts...
# 404438                                                     NA
# 83172                                                      NA

# %%
df['PNT_NM'].nunique(), df['PNT_NM'].nunique() / len(df)
# Out:
# (448, 0.0224)

# %%
df_subsample = df.sample(200)
df_subsample.head()
# Out:
#                   DATETIME_DTM                                 PNT_NM  \
# OBSRVTN_NB
# 108906     2021-05-14 09:30:00  Barricades around truck when required
# 340940     2023-04-17 09:58:00            Job Briefing (ED Switching)
# 432186     2024-01-30 13:30:00                        Personal Safety
# 209557     2022-02-05 13:00:00              Proper grounding utilized
# 393022     2023-09-13 12:02:00                            Minimum PPE
#
#                                                 QUALIFIER_TXT  \
# OBSRVTN_NB
# 108906                   Other - Barricades, Proper barricade
# 340940                  Job briefing conducted and documented
# 432186                                           Line of fire
# 209557                                      Other - Grounding
# 393022      All employees are wearing approved safety glas...
#
#                                            PNT_ATRISKNOTES_TX  \
# OBSRVTN_NB
# 108906      Talked with the crew about the barricade exten...
# 340940      None conducted, coached on the importance of j...
# 432186      Groundman was working below stapling pole grou...
# 209557      [NAME] identified previously placed grounds at...
# 393022      One [NAME] River employee was wearing non ANSI...
#
#                                        PNT_ATRISKFOLWUPNTS_TX
# OBSRVTN_NB
# 108906                                                     NA
# 340940                                                     NA
# 432186                                                     NA
# 209557                                                     NA
# 393022      Informed individual that OTG glasses need to b...

# %%
PROMPT = """
<|im_start|>system 
{0}
<|im_end|>

<|im_start|>user
{1}
<|im_end|>

<|im_start|>assistant
{2}
"""

# %%
class OneDecisionTest:
    def __init__(
            self,
            system_prompt: str,
            df: pd.DataFrame = df_subsample,
            model: str = 'llama2:latest',
            classes: Tuple[str] = ('True', 'False'),
        ):
        """Generate one decision for an llm to make. 

        Args:
            system_prompt (str): _description_
            classes (Tuple[str]): _description_
            df (pd.DataFrame): _description_
            model: _description
        """

        self._output = ollama.chat(
            model    = model, 
            messages = [{'role': 'system', 'content': system_prompt,},
                        {'role': 'user', 'content': 'what is 1+1?'}],#f'Based on the following info {df}, classify the data into these classes {classes}. Output only the class AND NOTHING ELSE.',}],
            #stream  = True,
            options  = {'temperature': 0}
        )
        print(self._output['message']['content'])
        # for chunk in self._llm_stream:
            # print(chunk['message']['content'], end='', flush=True)

OneDecisionTest(system_prompt='Your job is to do math.')
# Out:
# Oh, that's easy! The answer to 1+1 is... (drumroll please)... 2!

# %%
SYSTEM_PROMPT_FORMAT = """
You are a superintelligent Safety Classification and Learning (SCL) Model 
with the goal classifying field notes written on site by AEP electrical engineers and other essential personnel.

Your task is to reason with the field notes and output a classification for that field note data.
If there are figures in the class definitions, but not figures in the input data, use your best judgement to infer which class it belongs to.

The field notes have the following schema:
PNT_NM: Point name, the safety criteria being assessed. Forms a primary key when combined with OBSRVN_NB (observation number)
QUALIFIER_TXT: Qualifier text, list of predetermined observations chosen by the reviewer based on the point being assessed
PNT_ATRISKNOTES_TX: Point at-risk notes text, comments left by observer regarding unsafe conditions they found
PNT_ATRISKFOLWUPNTS_TX: Point at-risk follow up notes text, recommended remediation for at-risk conditions observed. This field may be empty (Indicated by "NA"). 

You must classify this data using these classes. The format of the classes is "class": -> "description of class":
{classes}

NOTE: your output should follow ONLY this json schema! (i.e. just output the classification and NOTHING else!)
schema:
{{ 'classification': enum{keys} }}
"""

USER_PROMPT_FORMAT = """
Below is the field notes:

{field_notes}

REMEMBER: 
your output should follow ONLY this json schema! (i.e. just output the classification and NOTHING else!)
schema:
{{ 'classification': enum{keys} }}
"""

class OneDecision:
    def __init__(
            self,
            classes: Dict[str, str],
            column_label: str,
            df: pd.DataFrame = df_subsample,
            model: str = 'llama3:latest',
        ):  
        """Generate one decision for an llm to make. """

        predictions = []

        prompt_classes = "\n".join(f"{k}: -> {v}" for k, v in classes.items())
        prompt_keys    = str(list(classes.keys()))

        #print(SYSTEM_PROMPT_FORMAT.format(classes="\n".join(f"{k}: -> {v}" for k, v in classes.items()), keys=str(list(classes.keys()))))

        for _, row in df.iterrows():
            prompt_field_notes = row[['PNT_NM', 'QUALIFIER_TXT', 'PNT_ATRISKNOTES_TX', 'PNT_ATRISKFOLWUPNTS_TX']].to_frame().to_string(index=True, header=False, max_colwidth=None)        
            
            #print(SYSTEM_PROMPT_FORMAT.format(classes=prompt_classes, keys=prompt_keys))
            print(prompt_field_notes)

            output = ollama.chat(
                model    = model, 
                messages = [{'role': 'system', 'content': SYSTEM_PROMPT_FORMAT.format(classes=prompt_classes, keys=prompt_keys)},
                            {'role': 'user', 'content': USER_PROMPT_FORMAT.format(field_notes=prompt_field_notes, keys=prompt_keys)}],
                options  = {'temperature': 0}
            )

            print(output['message']['content'])

        #df[column_label] = predictions

# %%
# incident_prompts = {
#     "suspended load": "A suspended load exceeding 500 lbs lifted more than 1 foot off the ground typically requires special equipment. This scenario exceeds the high-energy threshold.",
#     "fall from elevation": "A fall from over 4 feet of elevation, considering an average human weight of 150 lbs, exceeds the high-energy threshold.",
#     "Mobile Equipment/Traffic with Workers on Foot": "Most mobile equipment or vehicles in motion exceed the high-energy threshold due to their mass. The risk is from the worker's perspective, not the operator’s. In work zones, this applies when a vehicle veers within 6 feet of a worker or if a worker enters the traffic pattern.",
#     "Motor Vehicle incident (occupant)": "A motor vehicle crash at speeds of 30 mph or more exceeds the high-energy threshold, focusing on vehicle occupants, including the driver.",
#     "Heavy rotating equipment": "Heavy rotating equipment, beyond powered hand tools, typically exceeds the high-energy threshold due to the complexity of calculating mechanical energy.",
#     "High Temperature": "Substances at or above 150°F can cause third-degree burns with 2 seconds of contact, surpassing the high-energy threshold.",
#     "Steam": "Steam release always exceeds the high-energy threshold due to its high temperature and potential for burns.",
#     "Fire with Sustained Fuel Source": "Fires fueled by materials like paper burn at around 700°F, well above the high-energy threshold.",
#     "Explosion": "Any explosion exceeds the high-energy threshold due to the immense force released.",
#     "Excavation fr Trench": "Trench or excavation exposure deeper than 5 feet exceeds the high-energy threshold. Soil pressure increases by 40 lbs/ft² per foot of depth, reaching 200 lbs/ft² at 5 feet.",
#     "Electrical Contact with source": "Electrical contact at 50 volts or higher can cause serious injury or death, exceeding the high-energy threshold, per NFPA 70E.",
#     "Arc Flash": "Any arc flash exceeds the high-energy threshold due to high voltage. OSHA Standard 1910.333 defines safe distances.",
#     "High Dose of Chemical or Radiation": "Exposure to toxic chemicals, radiation, or environments reducing oxygen below 16 percent surpasses the high-energy threshold. Corrosive chemicals with pH <2 or >12.5 should be assessed by qualified personnel using IDLH values from the CDC."  
# }

high_energy_present = {
    'High Energy Incident ': """
    The field note is considered  High Energy Incident when it specifically references one of the following energy sources:
    [
    Suspended Load: 
        Most suspended loads require specialty equipment to lift more than 500 lbs of 
        load higher than 1 foot off the ground. In such a case, the suspended load would 
        be more than the high-energy threshold.

    Falling From Elevation: 
        Considering the average weight of a human is over 150 lbs, 4 feet of elevation 
        (measured from the ground surface to the bottom of the feet) exceeds the high- 
        energy threshold.
    
    Mobile Equipment/Traffic with Workers on Foot:
        Because of the mass, most mobile equipment, including motor vehicles, exceeds 
        the high-energy threshold when the equipment or vehicle is in motion. The 
        energy exposure is taken from the point of view of the worker on foot and not 
        the equipment operator or vehicle driver. 
        
        Note: For work zone traffic only, an incident occurs only when a vehicle departs 
        from the intended path of travel and is within 6 ft of an exposed employee or if 
        an employee enters the traffic pattern.

    Motor vehicle incident (occupant):
        Estimates of the motor vehicle speed typically involved in serious or fatal 
        crashes vary greatly from the National Transportation Safety Board, National 
        Highway Transportation Safety Association, and the U.S. Department of 
        Transportation. The team selected a conservative estimate of 30 miles per hour 
        as the high-energy threshold. This energy exposure is taken from the point of 
        view of the vehicle occupants, including the driver.

    Heavy Rotating Equipment:
        Computing mechanical energy can be complex, as it requires estimates of the 
        moment of inertia and angular velocity for rotating objects and stiffness and 
        displacement for tension or compression. Thus, all heavy rotating equipment 
        beyond powered hand tools typically exceed the high-energy threshold and 
        should be considered high-energy.

    High Temperature:
        According to the American Burn Association, exposure to any substance greater 
        than or equal to 150 degrees Fahrenheit typically cause third degree burns when 
        contacted for 2 seconds or more.

    Steam:
        According to the American Burn Association, any circumstance with the release 
        of steam exceeds the high-energy threshold.
    ]

    NOTE: the data should be classified as High Energy if one of the above precautions
    are relevant to the field notes.
    """,

    'No High Energy Incident': 'The field notes are not considered High Energy Incident.'
}

OneDecision(classes=high_energy_present, column_label='inv')
# Out:
# PNT_NM                                                                                                                                            Barricades around truck when required
# QUALIFIER_TXT                                                                                                                                      Other - Barricades, Proper barricade
# PNT_ATRISKNOTES_TX      Talked with the crew about the barricade extending from the truck and not creating a space at the rear of the truck that allows employees access to the vehicle
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                               NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                           Job Briefing (ED Switching)
# QUALIFIER_TXT                                                                          Job briefing conducted and documented
# PNT_ATRISKNOTES_TX      None conducted, coached on the importance of job brief. Employee said he forgot and it is important.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                    NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                               Personal Safety
# QUALIFIER_TXT                                                                                                                                           Line of fire
# PNT_ATRISKNOTES_TX      Groundman was working below stapling pole ground as a JL and AP - 5 in two separate buckets using various hand tools were working above him.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                            NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                         Proper grounding utilized
# QUALIFIER_TXT                                                                                                                                                                                                          Other - Grounding
# PNT_ATRISKNOTES_TX      [NAME] identified previously placed grounds at take off pole, however did not verify grounds on other side of work zone. Stopped and discussed and made sure bracket grounds were verified before starting work.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                  Minimum PPE
# QUALIFIER_TXT           All employees are wearing approved safety glasses w/side shields (ANSI Z87) Motion, High visibility reflective shirt/vest worn as the outer most layer (Class 3 where/when required) Motion
# PNT_ATRISKNOTES_TX                                                                   One [NAME] River employee was wearing non ANSI Z87 prescription glasses. One [NAME] River employee was wearing a class 2 vest.
# PNT_ATRISKFOLWUPNTS_TX                Informed individual that OTG glasses need to be purchased or ANSI Z87+ prescription glasses. Informed individual that [NAME] requires class 3 vests while working on roadway.
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                        Crew audit items (Forestry)
# QUALIFIER_TXT                                                                                                                         Herbicide equipment
# PNT_ATRISKNOTES_TX      Discussed with GF the opportunity to secure herbicide with a cable and lock per Texas Department of Agricultural recommendations.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                 NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                        Personal Safety (Forestry)
# QUALIFIER_TXT                                                                                                             Eyes on task, Hazard recognition, Line of fire
# PNT_ATRISKNOTES_TX      [NAME] failed to see the possible hazard of log rolling down hill with the set up they had decided on. We discussed and re - positioned rigging.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                 Circle of safety practices
# QUALIFIER_TXT                                                                                                                                            Other - Circle of safety
# PNT_ATRISKNOTES_TX      360 magnets not on some vehicles and some not being used. They should be inside the vehicle when driving not on the outside of the vehicle all the time..
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                         NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                   Tools/Equipment/Isolation
# QUALIFIER_TXT                                                                                                                                          Inspect tools and equipment
# PNT_ATRISKNOTES_TX      Observed and communicated that NES / RSOW sky climber equipment on site needed taken back to NES and that the equipment's annual inspection were past due.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                          NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                      Proper grounding utilized
# QUALIFIER_TXT                                                                                                                                                                                       Other - Grounding
# PNT_ATRISKNOTES_TX      Inspection of grounds and found a set with a damaged inspection sticker that couldn't be read clearly. Employee tagged grounds out of service to be sent for inspection and sticker replaced.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                             NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                       Correct work area traffic control
# QUALIFIER_TXT                                                                                  Closed off street, Other - Work Area Protection
# PNT_ATRISKNOTES_TX      This is a dangerous traffic area to work in, crew along with traffic did a good job of setting job and traffic control
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                      NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                                                    Personal Safety
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                                                                                  Line of fire, Pinch points
# PNT_ATRISKNOTES_TX      Spotter used when moving materials in laydown yard using front end loader with fork attachment. Observe spotter step over steel pole and stand in between poles laying next to front end loader operation. Discuss observation with loader operator and spotter pointing out potential pinch point / crush hazard and the importance of recognizing such hazards.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                                                 NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                           PPE
# QUALIFIER_TXT                                                                                                                                                                   Cut resistant gloves
# PNT_ATRISKNOTES_TX      I had to tell the 2 crew members to put gloves on. The crew was hand digging around old pole to try and remove it. The one crew member had trouble finding a pair of gloves.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                            NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                          PPE
# QUALIFIER_TXT                                                                                                                                                                                               Safety glasses adequate
# PNT_ATRISKNOTES_TX      One crew member was not wearing safety glasses. The crew member immediately retrieved the glasses and wore them accordingly. We discussed the importance of wearing the glasses to protect from eye injury.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                           NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                                Correct work area traffic control
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                                                                                Cones compliant, Signs out
# PNT_ATRISKNOTES_TX      [NAME] was set up on a corner street off of Southwest Blvd. taking the entire southbound lane. No signs or cones deployed. Worker stated they would normally use traffic control crew, but this set up only cones would be required. [NAME] no cones were used. We discussed AEPs expectations and requested this observation be discussed with his leadership.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                                               NA
# {'classification': 'No High Energy Incident'}
# PNT_NM                                                                                                            Walking and Working areas
# QUALIFIER_TXT                                                                                             Other - Walking and Working areas
# PNT_ATRISKNOTES_TX      [NAME] was using jack hammer periodically and have hearing protection sign or extra hearing protection for visitors
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                   NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                PPE
# QUALIFIER_TXT                                                                                                     Safety glasses adequate
# PNT_ATRISKNOTES_TX      crew member had safety glasses off do to glasses fogging up. advised him to clean glasses with fog glass cleaner.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                 NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                       Vehicle Set-up Correct
# QUALIFIER_TXT                                                                                                                                     Operator verified outriggers down
# PNT_ATRISKNOTES_TX      [NAME] side rear outrigger did not make complete contact with the ground due to the steep ditch so we placed two cross arms underneath the pad to secure it
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                           NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                Correct PIPE
# QUALIFIER_TXT                                                                                                                                                                                                                                                   Worn when required
# PNT_ATRISKNOTES_TX      Jib on material handler was within minimum approach distance and employees were in class 2 gloves and not sleeves. Employees were not in mad but jib was. Explained that any part of the vehicle encroaches mad truck must be barricaded and sleeves worn.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                          NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                         Correct work area traffic control
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                                                                       Other - Work Area Protection
# PNT_ATRISKNOTES_TX      [NAME] were working on a ROW but had to park the trucks along a township road with low volume traffic. [NAME] didn't place any signage or cones out. Spoke to the crew foreman who said he didn't bring any signs. I then spoke to their GF who said that he would get them some and would have his crews pick up additional signage in [NAME] tomorrow.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                                        NA
# {'classification': 'No High Energy Incident'}
# PNT_NM                                                                                                                  Barricades around truck when required
# QUALIFIER_TXT                                                                                                                                Proper barricade
# PNT_ATRISKNOTES_TX      Bucket truck barricade was to close to the truck and the digger barricade was down on the ground. Reminded them about the barricades.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                     NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                             Personal Safety
# QUALIFIER_TXT                                                                                                                                                Line of fire, Other - Personal Safety
# PNT_ATRISKNOTES_TX      Employee was dropping old conductor to the groud from height. His foreman stopped him and told him to come to the ground to bring down the old conductor. [NAME] complied.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                          NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                      Personal Safety
# QUALIFIER_TXT                                                                                                                                                                  Line of fire
# PNT_ATRISKNOTES_TX      Talked about a good practice procedure, use a rope sling to control a pole while loading the pole, instead of man - handling it, keeps you out of the line of fire.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                   NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                PPE
# QUALIFIER_TXT                                                                                                                                                                                        Hard hat adequate, Other - PPE, Work gloves adequate
# PNT_ATRISKNOTES_TX      Employees on Right of way using skid steer to ride on also did not have proper PPE on including Hard hat, Gloves and safety [NAME] vis vest according to TCR on site. According to AEP HIGH VISIBILITY policy from 2013 sharenow.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                 NA
# {"classification": "High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                             PPE - Workforce
# QUALIFIER_TXT                                                                                                                                                                                                                                                                              AEP Required (Standard)
# PNT_ATRISKNOTES_TX                                                                                                                                       Employee was helping cleanup trash off of a trailer as I observed I noticed all the employee had on was a hi - vis vest and no other shirt on underneath.
# PNT_ATRISKFOLWUPNTS_TX  Spoke with the employee and he said he had gotten covered in mud and took it off since they were finishing that task and leaving for the day. I advised him to please sit in the truck until they leave and to remember to bring some extra clothes while working in the muddy conditions.
# {'classification': 'No High Energy Incident'}
# PNT_NM                                                                                                                                                   PPE - Generation
# QUALIFIER_TXT                                                                                                                                             Protect Hearing
# PNT_ATRISKNOTES_TX      Summit employee was standing next to vacuum truck without hearing protection. Approached employee and had a conversation about wearing proper PPE
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                 NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                  Aerial Devices - Personal Protective Equipment
# QUALIFIER_TXT                                                                                                                                                                                                                                 Was the proper PPE worn?
# PNT_ATRISKNOTES_TX      Bucket truck operator had removed his Hi - vis [NAME] III vest while in the bucket trimming and had failed to put his vest back on while in the road chipping. [NAME] retrieved his vest from the truck to ensure he met the PPE requirements.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                              NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                            Excavation or Trench
# QUALIFIER_TXT                                                                                                                                                                                                  Barricaded as necessary
# PNT_ATRISKNOTES_TX      Observed an area of the worksite that had been excavated to run neutral lines in not properly barricaded. There was no work being performed at the time. The excavation was approximately 3' deep in sections.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                     Spoke with on - site safety and he had the area barricaded.
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                             Qualified observer
# QUALIFIER_TXT                                                                              Observer engagement, Primary observer not using cell phone
# PNT_ATRISKNOTES_TX      Another crew member was observed on his cell as a qualified observer ( [NAME] ). Entire group was coached on these two items.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                             NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                Equipment - Tools &Equipment
# QUALIFIER_TXT                                                                                                                      Inspected Daily
# PNT_ATRISKNOTES_TX      Fire extinguisher has not been inspected for current month. [NAME] daily inspections should be completed on all equipment.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                          NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                         Correct work area traffic control
# QUALIFIER_TXT                                                                                            Cones compliant, Order of traffic control installation, Professional WAP contractor use
# PNT_ATRISKNOTES_TX      Flagging crew started removing cones before DHE crew was out of roadway, coached on proper WAP installation and removal also no buffer zone on 45 mph section of roadway
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                        NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                Proper footwear
# QUALIFIER_TXT                                                                                                                                                                        Other - Footwear
# PNT_ATRISKNOTES_TX      LMA not wearing proper footwear when getting material from the storeroom in the morning, ( wearing tennis shoes, or something of that sort ) reminded them not to wear those.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                             NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                   Personal Safety (Forestry)
# QUALIFIER_TXT                                                                                                                                                                                                             Hazard recognition, Line of fire, Rushing
# PNT_ATRISKNOTES_TX      [NAME] failed to identify crossing busy road with gear as a hazard. All 5 crew members climbed gate and jumped down on other side to access ROW. There were two other access locations that wouldn't have required employees to climb gate.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                           NA
# {'classification': 'No High Energy Incident'}
# PNT_NM                                                                                     Did you recognize additional slip, trip, or fall hazards that had not already been recognized and mitigated? If so, please select or describe these hazards in the At-Risk notes.
# QUALIFIER_TXT                                                                                                                                                                                                     Other slip, trip, fall: please describe additional hazards
# PNT_ATRISKNOTES_TX      [NAME] member was in homeowners back yard and climbed over a chain link fence. [NAME] was asked if there was a gate on the other side of house and he said that there was. [NAME] was then informed to use it instead of climbing up and over fence.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                    NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                             Walking and Working areas
# QUALIFIER_TXT                                                                                                                                                                                              Other - Walking and Working areas
# PNT_ATRISKNOTES_TX      Observed two employees walking across muddy mats with their hands tucked into their pockets. Advised employees to remove hands from pockets to promote better center of gravity and prevent slips, trips, and falls.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                    NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                 Grounding trucks and trailers when required
# QUALIFIER_TXT                                                                                                      Truck grounding
# PNT_ATRISKNOTES_TX      truck with lifting boom was capible of reaching lines and we suggested to ground and barricade the vehicle
# PNT_ATRISKFOLWUPNTS_TX                                                                                                          NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                          Housekeeping - Generation
# QUALIFIER_TXT                                                                                                                                                                                 Cleanliness
# PNT_ATRISKNOTES_TX      THeir was a few items laying on the grating loose. Mostly trash and they were planning on taking it down when they went to break. I addressed the issue anyhow just as a reminder
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                 NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                      Personal Safety
# QUALIFIER_TXT                                                                                     Hazard recognition, Proper lifting, lowering and carrying
# PNT_ATRISKNOTES_TX      Old style pad mount transformer lifting handle is close to locking bolt cover and only allows for a fingertip grip when lifting lid
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                   NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                      Suspended Load/Overhead Work
# QUALIFIER_TXT                                              Employees protected from overhead loads, Other - Suspended Load/Overhead Work
# PNT_ATRISKNOTES_TX      Employees working below aerial bucket bolting in cross arms Employees dropping armor rods to ground from bucket.
# PNT_ATRISKFOLWUPNTS_TX                                              Keep employees out of drop zone. Do not air mail material to ground.
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                  Complete job briefing given
# QUALIFIER_TXT                                                                                                                                                                  Other - Job Briefing
# PNT_ATRISKNOTES_TX      Discussed completing job briefing. Provides clear plan for task, includes emergency info, identifies hazards may need to be mitigated. Job Briefing completed and resolved.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                           NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                        Aerial Devices - Procedures
# QUALIFIER_TXT                                                                                                                                                                                                        Does the bucket have a saw scabbard?
# PNT_ATRISKNOTES_TX      When trimmer aloft finished, he keep the pole saw out while he crossed back over the energized line. We discussed the need to put the saw away before crossing the line and stowing the bucket. This was re - affirmed by the RS.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                 NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                Complete job briefing given
# QUALIFIER_TXT                            All members of team present, Job briefing conducted and documented, Other - Job Briefing
# PNT_ATRISKNOTES_TX      Job brief wasn't completely filled out, not signed, and jobsite location was incorrect. Corrected onsite.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                         NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                                                                                           Correct PIPE
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                                                                                                                                     Other - IPE
# PNT_ATRISKNOTES_TX      One pair of sleeves had a date missing on one of the sleeves. We discussed this and I explained that it is the responsibility of each employee to check their PIPE and make sure its all within date and has the date on them. This sleeve was removed and foreman called to get a replacement. Also had the word put out across crews of the finding and encouraged them to double check their PIPE.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                                                                                     NA
# {'classification': 'No High Energy Incident'}
# PNT_NM                                                                                                                           Complete job briefing given (Forestry)
# QUALIFIER_TXT                                                                                                             911 Location / Hospital Info, Dispatch number
# PNT_ATRISKNOTES_TX      * Incorrect hospital was listed on the job briefing in relation to being the closest - corrected. * DDC was not listed on job briefing - added.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                               NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                        Correct work area traffic control
# QUALIFIER_TXT                                                                                                                                                                                   Cones compliant
# PNT_ATRISKNOTES_TX      [NAME] was parked off the road in a cul - de - sac. They did not have cones around the trucks. I advised them good idea to put cones out to make trucks visible even when off the road.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                       NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                                                                                                                                    THA
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                                                                                                                                      Hazards and Mitigation Controls Identified
# PNT_ATRISKNOTES_TX      THA did not acknowledge potential hazards that access road mats may pose to ground employees. At time of observation, multiple concrete trucks were traversing over mats causing some to flex, jar and jump under the weight of load. Advised crew to stay clear of access mats occupied by heavy equipment in travel. Recommended THA documentation includes situational awareness of mat movement due to heavy equipment in travel.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                                                                                                                     NA
# {'classification': 'No High Energy Incident'}
# PNT_NM                                                                                                                                                                                                                                                                                                                                                                                                                                     Cover up activities
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                                                                                                                                                                 Other - Cover up
# PNT_ATRISKNOTES_TX      The crew had a mechanical jumper taped on to a jumper on the top circuit with the rest of the jumper hanging down past the bottom circuit resting at the exposed system neutral. The crew should have used a linemans helper / T handle to temporarily attach the [NAME] head and properly cover different potentials. This crew also had an additional bucket working the pole and could have used there help to install this safety.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                                                                                                                      NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                         Personal Safety
# QUALIFIER_TXT                                                                                                                          Other - Personal Safety
# PNT_ATRISKNOTES_TX      Employee didn't have a traffic vest on during work. It was dark and on busy street. I told employee he needed to get one in the truck.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                      NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                            PPE - Generation
# QUALIFIER_TXT                                                                                                         Protect Head
# PNT_ATRISKNOTES_TX      Worker traveling in golf cart with no hard hat on. When approached, he understood and put his hard hat on.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                          NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                       PPE
# QUALIFIER_TXT                                                                                                                               Cut resistant gloves
# PNT_ATRISKNOTES_TX      Observed employee not wearing their gloves all the time while handling metal fencing. The supervisor immediately addressed this concern.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                        NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                       Wire Pulling Operations
# QUALIFIER_TXT                                                                                                                 Wire pulling/stringing/tensioning equipment barricaded
# PNT_ATRISKNOTES_TX      Barricade fence posts around the wire pulling equipment were missing caps to protect workers from injury. [NAME] was asked to add caps for added protection.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                            NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                   Housekeeping - Generation
# QUALIFIER_TXT                                                                       Job site hazards, Tripping Hazards, Walking / Working Surfaces
# PNT_ATRISKNOTES_TX      Housekeeping needed in the work area, electrical cords & welding lead lying in the walkways creating a slip / trip hazard.
# PNT_ATRISKFOLWUPNTS_TX                                                     Spoke with the employees and they moved everything out of the walkways.
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                             Rigging or Lifting
# QUALIFIER_TXT                                                          Tag lines in use to keep hands and fingers out of pinch points
# PNT_ATRISKNOTES_TX      The crew had failed to put out cones to mark their exclusion zone before going up in the air to perform work.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                             NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                                                                                                                                    SAFER Model
# ...
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                     Vehicle Set-up Correct (Forestry)
# QUALIFIER_TXT                                                                                              Wheel chocks used
# PNT_ATRISKNOTES_TX      One truck only had one wheel chock down while crew was parked for lunch. Addressed with crew members
# PNT_ATRISKFOLWUPNTS_TX                                                                                                    NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                      Pre-Job Briefing
# QUALIFIER_TXT                                                                                                       Other - Pre-Job Briefing
# PNT_ATRISKNOTES_TX      [NAME] was using a pre - job brief from the previous day. I spoke with crew foreman to fill out a new form everyday.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                    NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                            Qualified observer
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                             Clear communication, Primary observer not using cell phone
# PNT_ATRISKNOTES_TX      At times, the worker aloft could not hear the observer due to the distance he was standing away from the bucket. The observer also began to take a phone call until I reminded him not to let the phone distract him. [NAME] hung up immediately. I also recommended he move closer to the bucket so the worker aloft could hear him easier.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                            NA
# {'classification': 'No High Energy Incident'}
# PNT_NM                                                                                                                         Workplace Conditions Addressed
# QUALIFIER_TXT                                                                                                                                    Line of fire
# PNT_ATRISKNOTES_TX      Discussed hazards associated with employee leaning into open door of vehicle with minimal clearance on street side of passing traffic
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                     NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                      Equipment - Tools &Equipment
# QUALIFIER_TXT                                                                                                                     Satisfactory Condition
# PNT_ATRISKNOTES_TX      Backhoe was in use with a broken windshield. Could potentially limit visibility. The foreman said a new windshield was on order.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                          Pre-Job Briefing
# QUALIFIER_TXT                                                                                                                           Other - Pre-Job Briefing
# PNT_ATRISKNOTES_TX      AEP Contact was not listed, we talked about it. [NAME] had just gotten Carols number and he amended the Pre - Job to include her number.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                        NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                        Switching
# QUALIFIER_TXT                                                                                                                                                        ~Other - Switching
# PNT_ATRISKNOTES_TX      Distribution crew was unable to open B phase on pothead switch 1986. 3 Phase single tank regulator started growling during condition and switching was stopped.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                               NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                PPE
# QUALIFIER_TXT                                                                                                        Cut resistant gloves
# PNT_ATRISKNOTES_TX      Asked [NAME] Resources employee to wear hand protection when handling pole chain during unloading of pole at CCSC
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                 NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Cover up activities
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Cover other energized potentials
# PNT_ATRISKNOTES_TX      talked with crew foreman about needing to cover the cross arm as well when doing his cover up. Employee in bucket reached under the arm to assist other employee with making jumper up and kept looking over his shoulder to see if he was in the clear. Employee was in the zone and with in min approach distance to the energized wire and arm. Talked about if you are questioning if you are too close to something, then it needs to be covered. All other cover up was excellent at job site. This was this crews first week on the job. [NAME] was very nice and understood the reason.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                         Personal Safety
# QUALIFIER_TXT                                                                                                                                          Other - Personal Safety
# PNT_ATRISKNOTES_TX      One of the flaggers was wearing a cut off t - shirt. I spoke to him and he was going to put on his other hi - vis safety vest which had short sleeves.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                      NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                  9) Were special precautions documented on the job briefing?
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                               [Notes Required for At-Risk Conditions]
# PNT_ATRISKNOTES_TX      The crew was cautious to stay hydrated, however they were not aware of the company specific app to track hydration. On the way out of the job site the forester coached the foreman about leaving chainsaws on the ground rather than on a stump sticking over which might cause someone to accidentally hit their knee on.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                                           NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                                                                                                          Aerial Devices - Procedures
# QUALIFIER_TXT                                                                                                                                                                                                                                                                                  Was a drop zone established?
# PNT_ATRISKNOTES_TX      [NAME] was using drop zone cones more as a work area in backyard alley. Could condense the drop zone to where the tree crew was cutting since ground crew was inside the cones. The crew on the ground was not in line of fire. [NAME] should set out traffic cones as work area and not drop zone.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                                                                                                                   NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                        Equipment Operations near Energized Lines
# QUALIFIER_TXT                                                                                                      Barricades present to prevent incidental step and/or touch potential
# PNT_ATRISKNOTES_TX      Noticed a section of barricade was down around a crane / man basket, told employees to fix barricade and that all aerial equipment must be barricaded properly.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                               NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                      Hand and Power Tools
# QUALIFIER_TXT                                                                                                                                Right tool for the job (meets manufacturers intent)
# PNT_ATRISKNOTES_TX      The specialized bits for the oil containment where missing, instead of trying with the wrong tools the crew worked on another section while the bits where tracked down.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                        NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                             Complete job briefing given
# QUALIFIER_TXT                                                                                            Job briefing conducted and documented
# PNT_ATRISKNOTES_TX      One crew member did not sign onto the Job Brief. I addressed the issue with the crew and it was corrected immediately.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                      NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                     Complete job briefing given
# QUALIFIER_TXT                                                                                                                                             911 Location
# PNT_ATRISKNOTES_TX      911 location not descriptive enough to facilitate summoning medical help should need arise. Coached to both crew members the need for details.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                              NA
# {"classification": "No High Energy Incident"}
# PNT_NM                                                                                                                                                                                                        Cover up activities
# QUALIFIER_TXT                                                                                                                                                                                    Adequate amount of cover up used
# PNT_ATRISKNOTES_TX      Employee needed a larger blanket to cover the arm beyond the length of the preformed tie wire. Discussed this with the crew and they understood and committed to proper cover up practices in the future.
# PNT_ATRISKFOLWUPNTS_TX                                                                                                                                                                                                         NA
# {"classification": "No High Energy Incident"}

# %%
df_subsample
# Out:
#                   DATETIME_DTM                                     PNT_NM  \
# OBSRVTN_NB
# 108906     2021-05-14 09:30:00      Barricades around truck when required
# 340940     2023-04-17 09:58:00                Job Briefing (ED Switching)
# 432186     2024-01-30 13:30:00                            Personal Safety
# 209557     2022-02-05 13:00:00                  Proper grounding utilized
# 393022     2023-09-13 12:02:00                                Minimum PPE
# ...                        ...                                        ...
# 435223     2024-02-09 10:41:00  Equipment Operations near Energized Lines
# 372398     2023-07-11 09:37:00                       Hand and Power Tools
# 281152     2022-09-22 11:50:00                Complete job briefing given
# 420555     2023-12-11 12:30:00                Complete job briefing given
# 28286      2020-03-30 11:30:00                        Cover up activities
#
#                                                 QUALIFIER_TXT  \
# OBSRVTN_NB
# 108906                   Other - Barricades, Proper barricade
# 340940                  Job briefing conducted and documented
# 432186                                           Line of fire
# 209557                                      Other - Grounding
# 393022      All employees are wearing approved safety glas...
# ...                                                       ...
# 435223      Barricades present to prevent incidental step ...
# 372398      Right tool for the job (meets manufacturers in...
# 281152                  Job briefing conducted and documented
# 420555                                           911 Location
# 28286                        Adequate amount of cover up used
#
#                                            PNT_ATRISKNOTES_TX  \
# OBSRVTN_NB
# 108906      Talked with the crew about the barricade exten...
# 340940      None conducted, coached on the importance of j...
# 432186      Groundman was working below stapling pole grou...
# 209557      [NAME] identified previously placed grounds at...
# 393022      One [NAME] River employee was wearing non ANSI...
# ...                                                       ...
# 435223      Noticed a section of barricade was down around...
# 372398      The specialized bits for the oil containment w...
# 281152      One crew member did not sign onto the Job Brie...
# 420555      911 location not descriptive enough to facilit...
# 28286       Employee needed a larger blanket to cover the ...
#
#                                        PNT_ATRISKFOLWUPNTS_TX
# OBSRVTN_NB
# 108906                                                     NA
# 340940                                                     NA
# 432186                                                     NA
# 209557                                                     NA
# 393022      Informed individual that OTG glasses need to b...
# ...                                                       ...
# 435223                                                     NA
# 372398                                                     NA
# 281152                                                     NA
# 420555                                                     NA
# 28286                                                      NA
#
# [200 rows x 5 columns]
